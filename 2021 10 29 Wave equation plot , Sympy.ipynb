# %%
import numpy as np
import math
import sympy as sp
from sympy.plotting import plot

sp.init_printing(use_latex=True)

# %%
a=sp.symbols('a')
y=a+1

plot(y,(a,-5,5))

# %%
x, y, z=sp.symbols('x,y,z')

# %%
test=sp.cos((math.pi/2)*x+1)
test.sub(x,0)

plot(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-feb4e929d902> in <module>
#       1 test=sp.cos((math.pi/2)*x+1)
# ----> 2 test.sp.sub(x,0)
#       3
#       4 plot(test)
#
# AttributeError: 'cos' object has no attribute 'sp'

# %%
expr=sp.sin(2*x)+sp.cos(2*x)
expr_E=sp.expand_trig(expr)

plot(expr_E)

# %%
str_expr="x**2 + 3*x - 1/2"
expr=sp.sympify(str_expr)
expr
# Out:
#  2         1
# x  + 3⋅x - ─
#            2

# %%
x=sp.symbols('x')
a=sp.exp(2*x)
b=a.diff(x)

plot(b,(x,0,10))
# Out:
# 2*exp(2*x)

# %%
b
# Out:
#    2⋅x
# 2⋅ℯ

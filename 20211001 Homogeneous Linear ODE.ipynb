# %%
import matplotlib
import math
import numpy as np

# %%
array_test=np.array([[1,0],[0,1]])
print(array_test)
# Out:
# [[1 0]
#  [0 1]]

# %%
import sympy as sp

# %%
sp.init_printing(use_latex=True)

# %%
t=sp.symbols('t')
a=sp.symbols('a',cls=sp.Function)

# %%
d_eq=sp.Eq(sp.diff(a,t,2)-10*a(t),0)
d_eq
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-956cd2627f2e> in <module>
# ----> 1 d_eq=sp.Eq(sp.diff(a,t,2)-10*a(t),0)
#       2 d_eq
#
# ~\Anaconda3\envs\Qiskit\lib\site-packages\sympy\core\function.py in diff(f, *symbols, **kwargs)
#    2430     """
#    2431     if hasattr(f, 'diff'):
# -> 2432         return f.diff(*symbols, **kwargs)
#    2433     kwargs.setdefault('evaluate', True)
#    2434     return Derivative(f, *symbols, **kwargs)
#
# ~\Anaconda3\envs\Qiskit\lib\site-packages\sympy\core\expr.py in diff(self, *symbols, **assumptions)
#    3385     def diff(self, *symbols, **assumptions):
#    3386         assumptions.setdefault("evaluate", True)
# -> 3387         return Derivative(self, *symbols, **assumptions)
#    3388
#    3389     ###########################################################################
#
# ...

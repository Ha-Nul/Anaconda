# %%
import sympy as sp
import math

sp.init_printing(use_latex=True)

# %%
x=sp.symbols('x')
a,b=sp.symbols('a b')
f=sp.symbols('f',cls=sp.Function)
v=f(x)

# %%
d_eq=sp.Eq(sp.diff(f_1,x),-a*v-b*(x**2)*v)

# %%
sp.dsolve(d_eq,v)
# Out:
#              ⎛        2⎞
#              ⎜     b⋅x ⎟
#            x⋅⎜-a - ────⎟
#              ⎝      3  ⎠
# f(x) = C₁⋅ℯ

# %%
t=sp.symbols('t')
a=sp.symbols('a',cls=sp.Function)
y=a(t)

# %%
d_eq=sp.Eq(t*sp.diff(y,t)+y,2*t)

# %%
d_eq
# Out:
#   d
# t⋅──(a(t)) + a(t) = 2⋅t
#   dt

# %%
q=-a*v+b*(x**2)*v

# %%
q
# Out:
#              2
# -a⋅f(x) + b⋅x ⋅f(x)

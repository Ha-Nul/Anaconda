# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
import math

# %%
z=sp.symbols('z')
t=sp.symbols('t')
th=np.linspace(0,2*np.pi,50)

# %%
x=2*sp.cos(t)
y=2*np.sin(t)

# %%
x
# Out:
# 2*cos(z)

# %%
import numpy as np
import sympy as sp
import math
from sympy.plotting import plot
from sympy import I
from math import exp

sp.init_printing(use_latex=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-76538df1cd2c> in <module>
#       5 from sympy import I
#       6 from math import exp
# ----> 7 from sympy import hbar
#       8
#       9 sp.init_printing(use_latex=True)
#
# ImportError: cannot import name 'hbar'

# %%
def Potential_d(x1,y1,z1):
    d_coord=np.array([x1,y1,z1])
    return d_coord

def Potential_epsilon(x2,y2,z2):
                     
    epsil_coord=np.array([x2,y2,z2])
    epsil_size=np.linalg.norm(epsil_coord)
    epsil_unit=epsil_coord/epsil_size
    
    return epsil_unit

def Potential_V(phi,E):
    Var1=np.array([0,0,0,0,0,0])
                     
    for i in range(0,6,1):
        Var1[i]=float(input())
   
    VectorValue_d=Potential_d(Var1[0],Var1[1],Var1[2])
    VectorValue_epsilon=Potential_epsilon(Var1[3],Var1[4],Var1[5])
    exponentialValue=sp.exp(I*phi)
                     
    Ex_E_field=VectorValue_epsilon*2*E
    Potential=exponentialValue*np.dot(VectorValue_d,Ex_E_field)
    
    return Potential

# %%
t=sp.symbols('t')
a1=sp.symbols('a1',cls=sp.Function)
b1=(a1(t))
a2=sp.symbols('a2',cls=sp.Function)
b2=(a2(t))

phi=float(input("Value Phi"))
E=float(input("Value E"))

hbar=1.05457162000000*10**34
V=Potential_V(phi,E)

d_eq1=sp.Eq(sp.diff(b1,t),(-I/(2*hbar))*V*b2)
d_eq2=sp.Eq(sp.diff(b2,t),(-I/(2*hbar))*V*b1)

sol=sp.dsolve([d_eq1,d_eq2],ics={a1(0):1,a2(0):0})
# Out:
# Value Phi1
# Value E1
# 1
# 1
# 1
# 1
# 1
# 1
# ---------------------------------------------------------------------------
# SympifyError                              Traceback (most recent call last)
# <ipython-input-57-056b4d667571> in <module>
#      11 V=Potential_V(phi,E)
#      12
# ---> 13 d_eq1=sp.Eq(sp.diff(b1,t),(-I/(2*hbar))*V*b2)
#      14 d_eq2=sp.Eq(sp.diff(b2,t),(-I/(2*hbar))*V*b1)
#      15
#
# ~\Anaconda3\envs\Qiskit\lib\site-packages\sympy\core\relational.py in __new__(cls, lhs, rhs, **options)
#     493
#     494         lhs = _sympify(lhs)
# --> 495         rhs = _sympify(rhs)
#     496
#     497         evaluate = options.pop('evaluate', global_parameters.evaluate)
#
# ~\Anaconda3\envs\Qiskit\lib\site-packages\sympy\core\sympify.py in _sympify(a)
#     437
#     438     """
# --> 439     return sympify(a, strict=True)
#     440
#     441
#
# ~\Anaconda3\envs\Qiskit\lib\site-packages\sympy\core\sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     358
#     359     if strict:
# --> 360         raise SympifyError(a)
#     361
#     362     if iterable(a):
#
# SympifyError: SympifyError: array([-5.47473740275341e-35*I*a2(t)*exp(1.0*I),
#        -5.47473740275341e-35*I*a2(t)*exp(1.0*I),
#        -5.47473740275341e-35*I*a2(t)*exp(1.0*I)], dtype=object)

# %%
Var1=np.array([0,0,0,0,0,0])
                   
for i in range(0,6,1):
    Var1[i]=float(input())
    
exponential=sp.exp(I*phi)

VectorValue_d=Potential_d(Var1[0],Var1[1],Var1[2])
VectorValue_epsilon=Potential_epsilon(Var1[3],Var1[4],Var1[5])
exponentialValue=sp.exp(I*phi)
                     
Ex_E_field=VectorValue_epsilon*2*E
Potential=VectorValue_d*Ex_E_field*exponentialValue

print(Potential)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# [0.911684611677104*exp(1.0*I) 2.27921152919276*exp(1.0*I)
#  4.10258075254697*exp(1.0*I)]

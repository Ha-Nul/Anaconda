# %%
import numpy as np
import sympy as sp
import math
from sympy.plotting import plot
from sympy import I
from math import exp

sp.init_printing(use_latex=True)

# %%
t=sp.symbols('t')
a1=sp.symbols('a1',cls=sp.Function)
y1=(a1(t))
a2=sp.symbols('a2',cls=sp.Function)
y2=(a2(t))
h=sp.symbols('h')
V12,V21=sp.symbols('V12 V21')

d_eq1=sp.Eq(sp.diff(y1,t),(-I/(2*h))*V12*y2)
d_eq2=sp.Eq(sp.diff(y2,t),(-I/(2*h))*V21*y1)

sol=sp.dsolve([d_eq1,d_eq2],ics={a1(0):1,a2(0):0})

# %%
sol
# Out:
# ⎡             __________         __________                               ____
# ⎢         t⋅╲╱ -V₁₂⋅V₂₁     -t⋅╲╱ -V₁₂⋅V₂₁                            t⋅╲╱ -V₁
# ⎢         ──────────────    ────────────────                          ────────
# ⎢              2⋅h                2⋅h                     __________       2⋅h
# ⎢        ℯ                 ℯ                          ⅈ⋅╲╱ -V₁₂⋅V₂₁ ⋅ℯ
# ⎢a₁(t) = ─────────────── + ─────────────────, a₂(t) = ────────────────────────
# ⎣               2                  2                              2⋅V₁₂
#
# ______                        __________ ⎤
# ₂⋅V₂₁                    -t⋅╲╱ -V₁₂⋅V₂₁  ⎥
# ──────                   ────────────────⎥
#              __________        2⋅h       ⎥
#          ⅈ⋅╲╱ -V₁₂⋅V₂₁ ⋅ℯ                ⎥
# ────── - ────────────────────────────────⎥
#                       2⋅V₁₂              ⎦

# %%
sol[0]
# Out:
#              __________         __________
#          t⋅╲╱ -V₁₂⋅V₂₁     -t⋅╲╱ -V₁₂⋅V₂₁
#          ──────────────    ────────────────
#               2⋅h                2⋅h
#         ℯ                 ℯ
# a₁(t) = ─────────────── + ─────────────────
#                2                  2

# %%
print()

# %%
if h is float:
    print('None')
else:
    print('Something')
# Out:
# Something

# %%
print(type(V12))
print(type(V21))
print(type(h))
# Out:
# <class 'sympy.core.symbol.Symbol'>
# <class 'sympy.core.symbol.Symbol'>
# <class 'sympy.core.symbol.Symbol'>

# %%
V12=

# %%
plot(sol[0],(0,t,100))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-01cf8672a6e5> in <module>
# ----> 1 plot(sol[0],(0,t,100))
#
# ~\Anaconda3\envs\Qiskit\lib\site-packages\sympy\plotting\plot.py in plot(*args, **kwargs)
#    1640     series = []
#    1641     plot_expr = check_arguments(args, 1, 1)
# -> 1642     series = [LineOver1DRangeSeries(*arg, **kwargs) for arg in plot_expr]
#    1643
#    1644     plots = Plot(*series, **kwargs)
#
# TypeError: 'NoneType' object is not iterable

# %%
a3=sp.symbols('a3',cls=sp.Function)
y3=(a3(t))

d_eq3=sp.Eq(sp.diff(y3,t),2*y3)

# %%
sol3=sp.dsolve(d_eq3,ics={a3(0):1})
sol3

s_sol3=sol3

# %%
plot(s_sol3.rhs,(t,-100,100))

# %%
import numpy as np
import sympy as sp
import math
from sympy.plotting import plot
#from sympy.plotting import plot3d
from sympy import I
from math import exp

sp.init_printing(use_latex=True)

# %%
t=sp.symbols('x')
a1=sp.symbols('a1',cls=sp.Function)
y1=(a1(t))
a2=sp.symbols('a2',cls=sp.Function)
#h=sp.symbols('h')
#V12,V21=sp.symbols('V12 V21')
[V12,V21,h]=[2,-2,1.2]

d_eq1=sp.Eq(sp.diff(y1,x),(-I/(2*h))*V12*y2)
d_eq2=sp.Eq(sp.diff(y2,x),(-I/(2*h))*V21*y1)

sol=sp.dsolve([d_eq1,d_eq2],ics={a1(0):1,a2(0):0})

# %%
sol
# Out:
# ⎡                                   -1.0
# ⎢            ⎛ -0.833333333333333⋅x⎞            -0.833333333333333⋅x
# ⎣a₁(x) = 0.5⋅⎝ℯ                    ⎠     + 0.5⋅ℯ                    , a₂(x) =
#
#                              -1.0                              ⎤
#       ⎛ -0.833333333333333⋅x⎞              -0.833333333333333⋅x⎥
# 0.5⋅ⅈ⋅⎝ℯ                    ⎠     - 0.5⋅ⅈ⋅ℯ                    ⎦

# %%
sol[0].rhs
# Out:
#                            -1.0
#     ⎛ -0.833333333333333⋅x⎞            -0.833333333333333⋅x
# 0.5⋅⎝ℯ                    ⎠     + 0.5⋅ℯ

# %%
if h is float:
    print('None')
else:
    print('Something')
# Out:
# Something

# %%
print(type(V12))
print(type(V21))
print(type(h))
# Out:
# <class 'sympy.core.symbol.Symbol'>
# <class 'sympy.core.symbol.Symbol'>
# <class 'sympy.core.symbol.Symbol'>

# %%
[V12,V21,h]=[2,-2,1.2]
# Out:
# int

# %%
plot(sol[0].rhs,(x,0,10))

# %%
a3=sp.symbols('a3',cls=sp.Function)
y3=(a3(t))

d_eq3=sp.Eq(sp.diff(y3,t),2*y3)

# %%
sol3=sp.dsolve(d_eq3,ics={a3(0):1})
sol3

s_sol3=sol3

# %%
plot(s_sol3.rhs,(t,-10,10))
